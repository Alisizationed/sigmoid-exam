# %% [markdown]
# # **Security incidents**

# %% [markdown]
# ## **Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_palette('viridis')
sns.color_palette(palette='viridis')
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %%
plt.set_loglevel('warning')

# %% [markdown]
# ## **Load Dataset**

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# ## **Quick glare**

# %%
df.head()
# Out:
#              Timestamp Source IP Address Destination IP Address  Source Port  \
# 0  2023-05-30 06:33:58     103.216.15.12           84.9.164.252        31225
# 1  2020-08-26 07:08:30    78.199.217.198         66.191.137.154        17245
# 2  2022-11-13 08:23:25      63.79.210.48          198.219.82.17        16811
# 3  2023-07-02 10:38:46     163.42.196.10        101.228.192.255        20018
# 4  2023-07-16 13:11:07     71.166.185.76        189.243.174.238         6131
#
#    Destination Port Protocol  Packet Length Packet Type Traffic Type  \
# 0             17616     ICMP            503        Data         HTTP
# 1             48166     ICMP           1174        Data         HTTP
# 2             53600      UDP            306     Control         HTTP
# 3             32534      UDP            385        Data         HTTP
# 4             26646      TCP           1462        Data          DNS
#
#                                         Payload Data  ... Action Taken  \
# ...

# %% [markdown]
# ## **Encoding**

# %%
dummies = pd.get_dummies(df[cat_cols])
df = pd.concat([df, dummies.astype('int64')], axis=1)
df.drop(cat_cols, axis=1, inplace=True)

# %%
missing_cols = ['Malware Indicators', 'Firewall Logs',
                'IDS/IPS Alerts', 'Alerts/Warnings']

[print_col_unique(df, col) for col in missing_cols]

# %%
df[missing_cols] = df[missing_cols].notna().astype('int64')

# %% [markdown]
# ## **Feature Engineering**
